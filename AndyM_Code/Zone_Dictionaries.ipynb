# %%
import pandas as pd

# %%
# read in zone values of K

file = 'C:/users/Andrewm4/Documents/Hydro_572/GitHub/G572McHenryCountyGWModel/Chloride Inputs/zones_kvalues.csv'
df = pd.read_csv(file, index_col = 0)
df
# Out:
#           Kx   Kz
# Zones
# 1        0.0  0.0
# 2      300.0  6.0
# 3        0.0  0.0
# 4        0.0  0.0
# 5        0.0  0.0
# ...      ...  ...
# 86       0.0  0.0
# 87       0.0  0.0
# 88       0.0  0.0
# 89       0.0  0.0
# 90       0.0  0.0
#
# [90 rows x 2 columns]

# %%
# make into dictionary

zones_dict = df.to_dict('index')
zones_dict
# Out:
# {1: {'Kx': 0.0, 'Kz': 0.0},
#  2: {'Kx': 300.0, 'Kz': 6.0},
#  3: {'Kx': 0.0, 'Kz': 0.0},
#  4: {'Kx': 0.0, 'Kz': 0.0},
#  5: {'Kx': 0.0, 'Kz': 0.0},
#  6: {'Kx': 2.1955, 'Kz': 0.0271},
#  7: {'Kx': 0.0, 'Kz': 0.0},
#  8: {'Kx': 0.0, 'Kz': 0.0},
#  9: {'Kx': 16.0, 'Kz': 0.586831},
#  10: {'Kx': 0.0, 'Kz': 0.0},
#  11: {'Kx': 0.000764835, 'Kz': 1.09e-05},
#  12: {'Kx': 0.0004, 'Kz': 4e-06},
#  13: {'Kx': 0.901142, 'Kz': 0.000204601},
#  14: {'Kx': 2.60769, 'Kz': 0.007749032},
#  15: {'Kx': 0.02674525, 'Kz': 0.00014283},
#  16: {'Kx': 0.00024, 'Kz': 1.3e-05},
#  17: {'Kx': 0.0, 'Kz': 0.0},
#  18: {'Kx': 0.0, 'Kz': 0.0},
#  19: {'Kx': 0.0, 'Kz': 0.0},
#  20: {'Kx': 0.0, 'Kz': 0.0},
#  21: {'Kx': 0.0, 'Kz': 0.0},
#  22: {'Kx': 0.0, 'Kz': 0.0},
#  23: {'Kx': 1.3507, 'Kz': 0.04340576},
#  24: {'Kx': 0.0, 'Kz': 0.0},
#  25: {'Kx': 0.0, 'Kz': 0.0},
#  26: {'Kx': 0.076, 'Kz': 0.001756614},
#  27: {'Kx': 0.0, 'Kz': 0.0},
#  28: {'Kx': 1.7, 'Kz': 0.00113333},
# ...
